# %% [markdown]
# <a href="https://colab.research.google.com/github/peppe-sc/AML_project_poliTO/blob/test_AI/SemanticSegmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install tensorboardX
# Out:
# Mounted at /content/drive
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 1.0 MB/s eta 0:00:00
# ...

# %%
# !jar xvf  "/content/drive/MyDrive/AML/Cityscapes.zip"
# Out:
# Output streaming troncato alle ultime 5000 righe.
#  inflated: Cityscapes/Cityspaces/gtFine/train/strasbourg/strasbourg_000000_029577_gtFine_labelTrainIds.png
#  inflated: Cityscapes/Cityspaces/gtFine/train/strasbourg/strasbourg_000000_029729_gtFine_color.png
#  inflated: Cityscapes/Cityspaces/gtFine/train/strasbourg/strasbourg_000000_029729_gtFine_labelTrainIds.png
#  inflated: Cityscapes/Cityspaces/gtFine/train/strasbourg/strasbourg_000000_029839_gtFine_color.png
#  inflated: Cityscapes/Cityspaces/gtFine/train/strasbourg/strasbourg_000000_029839_gtFine_labelTrainIds.png
#  inflated: Cityscapes/Cityspaces/gtFine/train/strasbourg/strasbourg_000000_029915_gtFine_color.png
#  inflated: Cityscapes/Cityspaces/gtFine/train/strasbourg/strasbourg_000000_029915_gtFine_labelTrainIds.png
#  inflated: Cityscapes/Cityspaces/gtFine/train/strasbourg/strasbourg_000000_030017_gtFine_color.png
# ...

# %%
# !jar xvf  "/content/drive/MyDrive/AML/GTA5.zip"
# Out:
# Output streaming troncato alle ultime 5000 righe.
#  inflated: GTA5/images/00002.png
#  inflated: GTA5/images/00003.png
#  inflated: GTA5/images/00004.png
#  inflated: GTA5/images/00005.png
#  inflated: GTA5/images/00006.png
#  inflated: GTA5/images/00007.png
#  inflated: GTA5/images/00008.png
#  inflated: GTA5/images/00009.png
#  inflated: GTA5/images/00010.png
#  inflated: GTA5/images/00011.png
#  inflated: GTA5/images/00012.png
#  inflated: GTA5/images/00013.png
#  inflated: GTA5/images/00014.png
#  inflated: GTA5/images/00015.png
#  inflated: GTA5/images/00016.png
#  inflated: GTA5/images/00017.png
#  inflated: GTA5/images/00018.png
#  inflated: GTA5/images/00019.png
#  inflated: GTA5/images/00020.png
#  inflated: GTA5/images/00021.png
#  inflated: GTA5/images/00022.png
#  inflated: GTA5/images/00023.png
#  inflated: GTA5/images/00024.png
#  inflated: GTA5/images/00025.png
#  inflated: GTA5/images/00026.png
#  inflated: GTA5/images/00027.png
#  inflated: GTA5/images/00028.png
# ...

# %%
import os
import os.path

if not os.path.isdir('/content/AML_project_poliTO'):
  # !git clone -b test_AI https://github.com/peppe-sc/AML_project_poliTO.git
  # %cd AML_project_poliTO

if os.path.isdir('./AML_project_poliTO'):
  # %cd AML_project_poliTO


# !git pull origin test_AI
# Out:
# Cloning into 'AML_project_poliTO'...
# remote: Enumerating objects: 575, done.
# remote: Counting objects: 100% (352/352), done.
# remote: Compressing objects: 100% (163/163), done.
# remote: Total 575 (delta 225), reused 260 (delta 187), pack-reused 223
# Receiving objects: 100% (575/575), 368.87 MiB | 34.03 MiB/s, done.
# Resolving deltas: 100% (315/315), done.
# /content/AML_project_poliTO
# From https://github.com/peppe-sc/AML_project_poliTO
#  * branch            test_AI    -> FETCH_HEAD
# Already up to date.

# %%
# !python train.py --resume True --batch_size 8 --dataset CROSS_DOMAIN
# Out:
# CROSS_DOMAIN
# Dim batch_size
# 8
# training on CROSS_DOMAIN, training on GTA5 and validating on CityScapes
# root:  /content/Cityscapes/Cityspaces
# load pretrained model checkpoints/STDCNet813M_73.91.tar
# epoch 5, lr 0.009095:   6% 160/2496 [00:27<05:19,  7.30it/s, loss=0.827873]
